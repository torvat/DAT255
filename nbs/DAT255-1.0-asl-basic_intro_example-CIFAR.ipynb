# %% [markdown]
# A.S. Lundervold, v.060124

# %% [markdown]
# # Introduction

# %% [markdown]
# This is a first, straightforward example of using fastai for image classification. See Module 1 on the [course Canvas page](https://hvl.instructure.com/courses/25507) for more details.
#
# > This is not a stand-alone notebook. You must also work through the Module 1 notebooks from the [fastai course](https://course.fast.ai/) and the [fastai book](https://github.com/fastai/fastbook).

# %% [markdown]
# # Setup

# %% [markdown]
# **These first cells are included to make sure we can run the notebook locally and on both Google Colab and Kaggle:**

# %%
# This is a quick check of whether the notebook is currently running on Google Colaboratory
# or Kaggle, which makes some difference for the code below.
try:
    import google.colab
    colab=True
except:
    colab=False

import os
kaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')

# %%
# This is copied from Howard's notebook: https://www.kaggle.com/code/jhoward/is-it-a-bird-creating-a-model-from-your-own-data


#NB: Kaggle requires phone verification to use the internet or a GPU. If you haven't done that yet, the cell below will fail
#    This code is only here to check that your internet is enabled. It doesn't do anything else.
#    Here's a help thread on getting your phone number verified: https://www.kaggle.com/product-feedback/135367
import socket,warnings
try:
    socket.setdefaulttimeout(1)
    socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect(('1.1.1.1', 53))
except socket.error as ex: raise Exception("STOP: No internet. Click '>|' in top right and set 'Internet' switch to on")

# %%
# Make sure we're using the latest version of fastai
if colab:
    # !pip install -Uqq fastbook
    import fastbook
    fastbook.setup_book()

elif kaggle:
    # !pip install -Uqq fastai

else:
    # %pip install fastai
# Out:
# Requirement already satisfied: fastai in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.7.13)
# Requirement already satisfied: pandas in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (9.3.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: requests in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (2.28.1)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pyyaml in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (6.0.1)
# Requirement already satisfied: scikit-learn in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (1.4.0)
# Requirement already satisfied: torch<2.2,>=1.10 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (2.1.2+cu121)
# Requirement already satisfied: pip in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from fastai) (23.0.1)
# Requirement already satisfied: scipy in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (1.12.0)
# Requirement already satisfied: packaging in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (23.2)
# Requirement already satisfied: spacy<4 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (3.7.2)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (1.5.29)
# Requirement already satisfied: torchvision>=0.11 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (0.16.2+cu121)
# Requirement already satisfied: matplotlib in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastai) (3.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (0.9.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (2.5.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (1.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (4.66.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (1.24.1)
# Requirement already satisfied: jinja2 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from spacy<4->fastai) (65.5.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (0.3.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->fastai) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->fastai) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->fastai) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: filelock in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai) (3.9.0)
# Requirement already satisfied: fsspec in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai) (2023.4.0)
# Requirement already satisfied: sympy in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai) (1.12)
# Requirement already satisfied: networkx in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai) (3.0)
# Requirement already satisfied: typing-extensions in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch<2.2,>=1.10->fastai) (4.9.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->fastai) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->fastai) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->fastai) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->fastai) (4.47.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->fastai) (2023.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->fastai) (2023.3.post1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->fastai) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->fastai) (3.2.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.14.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai) (0.1.4)
# Requirement already satisfied: colorama in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->spacy<4->fastai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\torva\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch<2.2,>=1.10->fastai) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: C:\Users\Torva\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from pathlib import Path
if colab:
    from google.colab import drive
    drive.mount("/content/gdrive")
    DATA = Path('/content/gdrive/MyDrive/DAT255/')
    DATA.mkdir(exist_ok=True, parents=True)
    
elif kaggle:
    DATA = Path('/kaggle/input/')
else:
    DATA = Path("./data")

# %% [markdown]
# **Checking for GPU/MPS availability:**

# %% [markdown]
# If you're running on a Mac with Metal Performance Shaders (M-series), some features of PyTorch aren't supported. Therefore, we add a fallback:

# %%
import os
import torch

if torch.backends.mps.is_available():
    os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'

# %% [markdown]
# Then we check for GPU/MPS:

# %%
import fastai.torch_core

device = None
if torch.cuda.is_available():
    device = fastai.torch_core.default_device('cuda')
elif torch.backends.mps.is_available():
    device = fastai.torch_core.default_device('mps')
else:
    device = fastai.torch_core.default_device('cpu')

# %%
print(device)
# Out:
# cuda:0

# %% [markdown]
# > **Explanation:** The above code checks for the availability of a GPU or MPS (Metal Performance Shaders, used in Apple's M1/M2 chips) to accelerate model training. If neither is available, it defaults to using the CPU. Using GPU or MPS significantly speeds up deep learning tasks.

# %% [markdown]
# # Load and inspect some data

# %% [markdown]
# Let's keep things simple by using one of the data sets collected in the repository fast.ai Datasets (https://course.fast.ai/datasets). You'll find the options using the previous link, or by looking at list of `URLs`:

# %%
from fastai.data.all import URLs

# %%
print([d for d in dir(URLs) if "__" not in d])
# Out:
# ['ADULT_SAMPLE', 'AG_NEWS', 'AMAZON_REVIEWS', 'AMAZON_REVIEWS_POLARITY', 'BIWI_HEAD_POSE', 'BIWI_SAMPLE', 'CALTECH_101', 'CAMVID', 'CAMVID_TINY', 'CARS', 'CIFAR', 'CIFAR_100', 'COCO_SAMPLE', 'COCO_TINY', 'CUB_200_2011', 'DBPEDIA', 'DOGS', 'FLOWERS', 'FOOD', 'GOOGLE', 'HUMAN_NUMBERS', 'IMAGENETTE', 'IMAGENETTE_160', 'IMAGENETTE_320', 'IMAGEWANG', 'IMAGEWANG_160', 'IMAGEWANG_320', 'IMAGEWOOF', 'IMAGEWOOF_160', 'IMAGEWOOF_320', 'IMDB', 'IMDB_SAMPLE', 'LOCAL_PATH', 'LSUN_BEDROOMS', 'MACAQUES', 'MDL', 'ML_100k', 'ML_SAMPLE', 'MNIST', 'MNIST_SAMPLE', 'MNIST_TINY', 'MNIST_VAR_SIZE_TINY', 'MT_ENG_FRA', 'OPENAI_TRANSFORMER', 'PASCAL_2007', 'PASCAL_2012', 'PETS', 'PLANET_SAMPLE', 'PLANET_TINY', 'S3', 'S3_AUDI', 'S3_COCO', 'S3_IMAGE', 'S3_IMAGELOC', 'S3_MODEL', 'S3_NLP', 'SIIM_SMALL', 'SOGOU_NEWS', 'TCGA_SMALL', 'URL', 'WIKITEXT', 'WIKITEXT_TINY', 'WT103_BWD', 'WT103_FWD', 'YAHOO_ANSWERS', 'YELP_REVIEWS', 'YELP_REVIEWS_POLARITY', 'ZEBRA_FINCH', 'path']

# %% [markdown]
# **Loading the CIFAR-10 dataset:**

# %% [markdown]
# We'll use a famous benchmark data set widely studied by the computer vision community: [Cifar-10](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# This dataset comprises 60,000 32x32 color images divided into 10 different classes, each representing a distinct category, such as airplanes, cars, birds, cats, etc. With 6,000 images per category, CIFAR-10 offers a balanced dataset that is both challenging and accessible for beginners in deep learning.
#
# <img src="https://raw.githubusercontent.com/HVL-ML/DAT255/main/nbs/assets/cifar-10.png">
#
# Our goal is to create an image classifier. More specifically, this notebook is designed to guide you through using `fastai` to build a model that can accurately classify images from the CIFAR-10 dataset.

# %%
from fastai.vision.all import *
# Download and prepare the CIFAR-10 dataset
path = untar_data(URLs.CIFAR)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='168173568' class='' max='168168549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [168173568/168168549 00:12&lt;00:00]
#     </div>

# %% [markdown]
# > **Explanation:** We import all necessary modules from the FastAI vision library here. The untar_data function is then used to download and extract the CIFAR-10 dataset from FastAI's dataset repository. This function simplifies the process of acquiring and preparing data for use.

# %%
path.ls()
# Out:
# (#3) [Path('C:/Users/Torva/.fastai/data/cifar10/labels.txt'),Path('C:/Users/Torva/.fastai/data/cifar10/test'),Path('C:/Users/Torva/.fastai/data/cifar10/train')]

# %%
get_image_files(path)[:5]
# Out:
# (#5) [Path('C:/Users/Torva/.fastai/data/cifar10/test/airplane/1001_airplane.png'),Path('C:/Users/Torva/.fastai/data/cifar10/test/airplane/1010_airplane.png'),Path('C:/Users/Torva/.fastai/data/cifar10/test/airplane/1018_airplane.png'),Path('C:/Users/Torva/.fastai/data/cifar10/test/airplane/1022_airplane.png'),Path('C:/Users/Torva/.fastai/data/cifar10/test/airplane/1023_airplane.png')]

# %% [markdown]
# **Creating a DataBlock:**

# %%
data = DataBlock(
    blocks=(ImageBlock, CategoryBlock),             # Define data types for the input and output
    get_items=get_image_files,                      # Function to get image files
    splitter=GrandparentSplitter(train_name='train', 
                                 valid_name='test'),# Split data based on grandparent folder name
    get_y=parent_label,                             # Get labels from parent folder names
    item_tfms=Resize(224),                          # Resize images to 224x224
    batch_tfms=[
        *aug_transforms(),                          # Apply some data augmentation (see Chapter 2)
        Normalize.from_stats(*imagenet_stats)       # Normalize image intensities (because pretraining)
    ]
)

# %% [markdown]
# > **Explanation:** This sets up a DataBlock, a versatile FastAI tool for building datasets. It specifies the data types (images and categories), how to retrieve images and labels, and how to split the dataset (80% for training and 20% for validation). The item_tfms and batch_tfms apply transformations such as resizing and data augmentation, which are crucial for improving model robustness and handling varying image sizes.

# %%
dls = data.dataloaders(path, bs=64)

# %%
dls.show_batch()

# %% [markdown]
# We can inspect the effect of data augmentation on an image by passing in the `unique=True` argument to `show_batch()`:

# %%
dls.show_batch(unique=True)

# %% [markdown]
# # Train a model

# %% [markdown]
# We use a version of the ResNet34 model pre-trained on the ImageNet dataset. This architecture reasonably balances performance and complexity and is often an excellent first choice.

# %%
learn = vision_learner(dls, resnet34, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to C:\Users\Torva/.cache\torch\hub\checkpoints\resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:04<00:00, 18.2MB/s]

# %%
# Train the model for 1 epoch with everything frozen except head, then 4 unfrozen
learn.fine_tune(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.584287</td>
#       <td>0.362626</td>
#       <td>0.876100</td>
#       <td>03:22</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.283429</td>
#       <td>0.206472</td>
#       <td>0.928600</td>
#       <td>03:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.207804</td>
#       <td>0.162368</td>
#       <td>0.945300</td>
#       <td>03:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.112447</td>
#       <td>0.123235</td>
#       <td>0.957400</td>
#       <td>03:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.054568</td>
#       <td>0.109796</td>
#       <td>0.963100</td>
#       <td>03:38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > **Explanation:** Here, we use FastAI's `vision_learner` to create a convolutional neural network based on the ResNet34 architecture, a popular choice for image classification. The `fine_tune` method trains the model by first adjusting the parameters of new layers added for our specific task and then adjusting the parameters of the entire network. The number 4 indicates the number of epochs or complete passes through the dataset.

# %% [markdown]
# # Evaluate

# %% [markdown]
# Here are some results:

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# We obtain an accuracy of about 96.4%, which means that

# %% [markdown]
# 360 of the test images were misclassified:

# %%
10000*(1-0.964)
# Out:
# 360.00000000000034

# %% [markdown]
# Let's dig more into the misclassifications:

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.most_confused()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('cat', 'dog', 50),
#  ('dog', 'cat', 48),
#  ('automobile', 'truck', 18),
#  ('truck', 'automobile', 17),
#  ('airplane', 'ship', 15),
#  ('cat', 'bird', 15),
#  ('deer', 'cat', 11),
#  ('dog', 'deer', 10),
#  ('horse', 'dog', 10),
#  ('bird', 'deer', 9),
#  ('bird', 'frog', 9),
#  ('bird', 'airplane', 8),
#  ('cat', 'frog', 8),
#  ('bird', 'cat', 7),
#  ('deer', 'bird', 7),
#  ('deer', 'horse', 7),
#  ('ship', 'airplane', 7),
#  ('airplane', 'truck', 6),
#  ('cat', 'deer', 6),
#  ('frog', 'cat', 6),
#  ('truck', 'ship', 6),
#  ('bird', 'dog', 5),
#  ('dog', 'bird', 5),
#  ('horse', 'deer', 5),
#  ('cat', 'ship', 4),
#  ('deer', 'airplane', 4),
#  ('dog', 'horse', 4),
#  ('frog', 'bird', 4),
#  ('truck', 'airplane', 4),
#  ('bird', 'ship', 3),
#  ('cat', 'airplane', 3),
#  ('dog', 'frog', 3),
#  ('airplane', 'automobile', 2),
#  ('airplane', 'bird', 2),
#  ('airplane', 'cat', 2),
#  ('automobile', 'airplane', 2),
#  ('automobile', 'ship', 2),
#  ('bird', 'horse', 2),
#  ('cat', 'horse', 2),
#  ('cat', 'truck', 2),
#  ('deer', 'dog', 2),
#  ('frog', 'airplane', 2),
#  ('frog', 'dog', 2),
#  ('horse', 'bird', 2),
#  ('ship', 'automobile', 2),
#  ('cat', 'automobile', 1),
#  ('deer', 'frog', 1),
#  ('dog', 'truck', 1),
#  ('frog', 'truck', 1),
#  ('horse', 'airplane', 1),
#  ('horse', 'cat', 1),
#  ('horse', 'truck', 1),
#  ('ship', 'frog', 1)]

# %% [markdown]
# Here are the images that were misclassified with the highest loss / greatest confidence:

# %%
interp.plot_top_losses(15, nrows=3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# > This was a simple example. Later, we'll learn many tricks that can be used to increase performance. In fact, CIFAR10 turns out to be way too simple as a benchmark dataset for modern deep learning-based computer vision methods.

# %% [markdown]
# # Your turn!

# %% [markdown]
# **Experiment with different architectures**

# %% [markdown]
# > Beyond ResNet34, explore other neural network architectures like ResNet50, AlexNet, or VGG16. Observe how the choice of architecture impacts training time and accuracy.

# %% [markdown]
# **Hyperparameter tuning**

# %% [markdown]
# > Experiment with different learning rates, batch sizes, and numbers of epochs. Understand how these hyperparameters affect the model's performance and training dynamics.

# %% [markdown]
# **Error analysis**

# %% [markdown]
# > Dive deeper into the misclassified images. Try to find patterns or common characteristics among these errors. This can lead to insights about the dataset, model, and potential areas for improvement.

# %% [markdown]
# **Different data set**

# %% [markdown]
# > Try out the same approach on a different data set. For example, try the PETS dataset.
